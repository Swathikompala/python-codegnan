# %%
class Bank:
    def __init__(self,username,password,amount):
        self.username = username #Public attribute
        self._password = password #Protected attribute 
        self.__amount = amount #Private attribute
    def withdraw(self, withdraw_amount): #Public method
        if self.__amount >= withdraw_amount:
            self.__amount -= withdraw_amount
            return f'withdraw successful and current balance is {self.__amount}'
        else:
            return "Insufficient amount"
    def deposite(self, deposite_amount):#Public method
            
            
            self.__amount += deposite_amount
            return f'deposite successful and current balance is {self.__amount}'
    def _total_users(self):#Private method
            return "Total users is 101"

#Creating object for the bank 
b = Bank('anu','chiky',1000)
print(b.username)
print(b.deposite(100))
print(b.withdraw(10))
print(b._password)# Protected member access
print(b._Bank__amount)#Private member acess using name mangling 
print(b._Bank__total_users())#Private method access using name mangling
# Out:
# anu
# deposite successful and current balance is 1100
# withdraw successful and current balance is 1090
# chiky
# 1090
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 27
#      25 print(b._password)# Protected member access
#      26 print(b._Bank__amount)#Private member acess using name mangling
# ---> 27 print(b._Bank__total_users())#Private method access using name mangling
#
# AttributeError: 'Bank' object has no attribute '_Bank__total_users'

# %%
from bank import Bank

#Creating object for the bank
b = Bank('anu'.'chiky',1000)
print(b.__amount)
print(b.username)
print(b._password)
# Out:
#   Cell In[5], line 4
#     b = Bank('anu'.'chiky',1000)
#                    ^
# SyntaxError: invalid syntax
